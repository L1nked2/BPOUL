# %%
pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.9.50)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: requests-file in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (1.4.0)
# Requirement already satisfied: lxml in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: requests>=2.3.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (1.22.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (1.26.9)
# Requirement already satisfied: six in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->finance-datareader) (0.4.4)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.6.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: numpy>=1.19 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX-MARCAP')
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          62900          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         624000          1
# 2     000660  KR7000660001    SK하이닉스  KOSPI          93500          1
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         900000          2
# 4     051910  KR7051910008      LG화학  KOSPI         737000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2665  308700  KR7308700004       테크엔  KONEX  일반기업부     590          1
# 2666  267810  KR7267810000        앙츠  KONEX  일반기업부    1150          2
# 2667  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2668  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2669  329020  KR7329020002      오션스톤  KONEX  일반기업부    1800          0
#
#       Changes  ChagesRatio    Open    High     Low    Volume         Amount  \
# 0        2500         4.14   63100   63200   62300  20037163  1257129641861
# 1       19000         3.14  623000  629000  613000    447112   278189137000
# 2        4400         4.94   95200   95300   92500   5002149   468889493882
# 3       -7000        -0.77  917000  920000  898000     70747    64085170000
# 4       42000         6.04  730000  744000  724000    304326   223654762000
# ...       ...          ...     ...     ...     ...       ...            ...
# 2665       40         7.27     600     600     468       129          73258
# 2666      -15        -1.29    1300    1300    1150         7           8800
# 2667        0         0.00       0       0       0         0              0
# 2668        0         0.00       0       0       0         0              0
# 2669        0         0.00       0       0       0         0              0
#
#                Marcap      Stocks MarketId
# 0     375499322395000  5969782550      STK
# 1     146016000000000   234000000      STK
# 2      68068221127500   728002365      STK
# 3      64056600000000    71174000      STK
# 4      52026556791000    70592343      STK
# ...               ...         ...      ...
# 2665       2360000000     4000000      KNX
# 2666       2055050000     1787000      KNX
# 2667       1934959392     2121666      KNX
# 2668       1654666524     9141804      KNX
# 2669       1503273600      835152      KNX
#
# [2670 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df_krx["Marcap"])
plt.show()

# %%
num_stocks = 300

plt.plot(df_krx["Marcap"][:num_stocks])
plt.show()

# %%
start_date = '2010-12-30'
end_date = '2021-12-30'
df_list = []

for code in df_krx["Code"][:num_stocks]:
    series_close = fdr.DataReader(code, start_date, end_date)["Close"]
    df_list.append(series_close)

df_close = pd.concat(df_list, axis=1)
df_close.columns = df_krx["Name"][:num_stocks]
df_close
# Out:
# Name         삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스    LG화학   삼성SDI  삼성전자우     현대차  \
# Date
# 2010-12-30  18980       NaN   24000       NaN  391000  168000  12980  173500
# 2011-01-03  19160       NaN   25300       NaN  390500  178000  13740  177000
# 2011-01-04  19160       NaN   25600       NaN  395000  179000  13820  178000
# 2011-01-05  18840       NaN   25900       NaN  418000  178000  13580  189000
# 2011-01-06  18600       NaN   26100       NaN  418000  180500  13420  194000
# ...           ...       ...     ...       ...     ...     ...    ...     ...
# 2021-12-24  80500       NaN  128000  874642.0  621000  651000  72800  215500
# 2021-12-27  80200       NaN  126000  875631.0  627000  644000  72400  213500
# 2021-12-28  80300       NaN  127500  880572.0  632000  651000  72400  214000
# 2021-12-29  78800       NaN  127000  879584.0  628000  663000  71700  212000
# 2021-12-30  78300       NaN  131000  892432.0  615000  655000  71200  209000
#
# Name         NAVER     기아  ...    씨아이에스  와이지엔터테인먼트     일동제약  바이오니아  한올바이오파마  \
# Date                       ...
# 2010-12-30   71256  50600  ...      NaN        NaN      NaN   4586     7360
# 2011-01-03   69529  52500  ...      NaN        NaN      NaN   4656     6990
# 2011-01-04   69529  55100  ...      NaN        NaN      NaN   4577     7030
# 2011-01-05   69843  56900  ...      NaN        NaN      NaN   4470     7050
# 2011-01-06   69529  57100  ...      NaN        NaN      NaN   4437     6970
# ...            ...    ...  ...      ...        ...      ...    ...      ...
# 2021-12-24  384000  85100  ...  13950.0    53400.0  26750.0  51300    20700
# 2021-12-27  380500  84800  ...  14200.0    54500.0  27200.0  47550    21500
# 2021-12-28  384500  84500  ...  14350.0    57100.0  27050.0  47000    21150
# 2021-12-29  382000  83400  ...  14400.0    55800.0  30300.0  49950    21350
# 2021-12-30  378500  82200  ...  14400.0    55700.0  33600.0  48600    21050
#
# Name        에이프로젠  삼천당제약  LG전자우    파크시스템스     대상
# Date
# 2010-12-30  26000   2140  41092       NaN   7720
# 2011-01-03  25617   2135  42545       NaN   7800
# 2011-01-04  25521   2150  42264       NaN   7900
# 2011-01-05  25378   2140  40905       NaN   7910
# 2011-01-06  25378   2135  41233       NaN   7860
# ...           ...    ...    ...       ...    ...
# 2021-12-24   1525  42600  65400  146200.0  23450
# 2021-12-27   1575  42550  66300  154400.0  23550
# 2021-12-28   1530  43400  66800  157000.0  23900
# 2021-12-29   1645  44200  66900  153600.0  23350
# 2021-12-30   1685  43350  65500  153000.0  23300
#
# [2712 rows x 300 columns]

# %%
df_close = df_close.dropna(axis=1)
df_close
# Out:
# Name         삼성전자  SK하이닉스    LG화학   삼성SDI  삼성전자우     현대차   NAVER     기아  \
# Date
# 2010-12-30  18980   24000  391000  168000  12980  173500   71256  50600
# 2011-01-03  19160   25300  390500  178000  13740  177000   69529  52500
# 2011-01-04  19160   25600  395000  179000  13820  178000   69529  55100
# 2011-01-05  18840   25900  418000  178000  13580  189000   69843  56900
# 2011-01-06  18600   26100  418000  180500  13420  194000   69529  57100
# ...           ...     ...     ...     ...    ...     ...     ...    ...
# 2021-12-24  80500  128000  621000  651000  72800  215500  384000  85100
# 2021-12-27  80200  126000  627000  644000  72400  213500  380500  84800
# 2021-12-28  80300  127500  632000  651000  72400  214000  384500  84500
# 2021-12-29  78800  127000  628000  663000  71700  212000  382000  83400
# 2021-12-30  78300  131000  615000  655000  71200  209000  378500  82200
#
# Name          셀트리온     카카오  ...     태광산업  차바이오텍   삼양식품    동원산업  바이오니아  \
# Date                        ...
# 2010-12-30   28015   15495  ...  1262000  10197  18050  138000   4586
# 2011-01-03   28056   15415  ...  1266000  10430  18150  141500   4656
# 2011-01-04   27597   15575  ...  1271000  10570  17900  141500   4577
# 2011-01-05   27847   15655  ...  1309000  10757  18150  142000   4470
# 2011-01-06   28517   15696  ...  1340000  11200  18050  139500   4437
# ...            ...     ...  ...      ...    ...    ...     ...    ...
# 2021-12-24  197278  114500  ...   994000  19000  91900  232000  51300
# 2021-12-27  200222  113000  ...   986000  20000  93900  233000  47550
# 2021-12-28  212000  113500  ...   993000  19900  94600  234000  47000
# 2021-12-29  201000  114000  ...  1074000  20000  95100  229500  49950
# 2021-12-30  198000  112500  ...  1043000  19950  94800  227000  48600
#
# Name        한올바이오파마  에이프로젠  삼천당제약  LG전자우     대상
# Date
# 2010-12-30     7360  26000   2140  41092   7720
# 2011-01-03     6990  25617   2135  42545   7800
# 2011-01-04     7030  25521   2150  42264   7900
# 2011-01-05     7050  25378   2140  40905   7910
# 2011-01-06     6970  25378   2135  41233   7860
# ...             ...    ...    ...    ...    ...
# 2021-12-24    20700   1525  42600  65400  23450
# 2021-12-27    21500   1575  42550  66300  23550
# 2021-12-28    21150   1530  43400  66800  23900
# 2021-12-29    21350   1645  44200  66900  23350
# 2021-12-30    21050   1685  43350  65500  23300
#
# [2712 rows x 200 columns]

# %%
df_returns = df_close.pct_change()
df_returns = df_returns.iloc[1:, :]
df_returns
# Out:
# Name            삼성전자    SK하이닉스      LG화학     삼성SDI     삼성전자우       현대차  \
# Date
# 2011-01-03  0.009484  0.054167 -0.001279  0.059524  0.058552  0.020173
# 2011-01-04  0.000000  0.011858  0.011524  0.005618  0.005822  0.005650
# 2011-01-05 -0.016701  0.011719  0.058228 -0.005587 -0.017366  0.061798
# 2011-01-06 -0.012739  0.007722  0.000000  0.014045 -0.011782  0.026455
# 2011-01-07 -0.009677  0.000000 -0.005981 -0.013850 -0.011923  0.020619
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-24  0.007509  0.003922 -0.020505  0.012442  0.006916  0.031100
# 2021-12-27 -0.003727 -0.015625  0.009662 -0.010753 -0.005495 -0.009281
# 2021-12-28  0.001247  0.011905  0.007974  0.010870  0.000000  0.002342
# 2021-12-29 -0.018680 -0.003922 -0.006329  0.018433 -0.009669 -0.009346
# 2021-12-30 -0.006345  0.031496 -0.020701 -0.012066 -0.006974 -0.014151
#
# Name           NAVER        기아      셀트리온       카카오  ...      태광산업     차바이오텍  \
# Date                                                ...
# 2011-01-03 -0.024237  0.037549  0.001464 -0.005163  ...  0.003170  0.022850
# 2011-01-04  0.000000  0.049524 -0.016360  0.010380  ...  0.003949  0.013423
# 2011-01-05  0.004516  0.032668  0.009059  0.005136  ...  0.029898  0.017692
# 2011-01-06 -0.004496  0.003515  0.024060  0.002619  ...  0.023682  0.041182
# 2011-01-07  0.015806  0.021016  0.002946  0.024274  ...  0.009701 -0.030179
# ...              ...       ...       ...       ...  ...       ...       ...
# 2021-12-24  0.015873  0.010689  0.000000  0.013274  ...  0.014286  0.002639
# 2021-12-27 -0.009115 -0.003525  0.014923 -0.013100  ... -0.008048  0.052632
# 2021-12-28  0.010512 -0.003538  0.058825  0.004425  ...  0.007099 -0.005000
# 2021-12-29 -0.006502 -0.013018 -0.051887  0.004405  ...  0.081571  0.005025
# 2021-12-30 -0.009162 -0.014388 -0.014925 -0.013158  ... -0.028864 -0.002500
#
# Name            삼양식품      동원산업     바이오니아   한올바이오파마     에이프로젠     삼천당제약  \
# Date
# 2011-01-03  0.005540  0.025362  0.015264 -0.050272 -0.014731 -0.002336
# 2011-01-04 -0.013774  0.000000 -0.016967  0.005722 -0.003748  0.007026
# 2011-01-05  0.013966  0.003534 -0.023378  0.002845 -0.005603 -0.004651
# 2011-01-06 -0.005510 -0.017606 -0.007383 -0.011348  0.000000 -0.002336
# 2011-01-07  0.008310 -0.003584 -0.011494 -0.021521  0.003743  0.000000
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-24 -0.015005  0.022026 -0.039326  0.002421  0.009934 -0.026286
# 2021-12-27  0.021763  0.004310 -0.073099  0.038647  0.032787 -0.001174
# 2021-12-28  0.007455  0.004292 -0.011567 -0.016279 -0.028571  0.019976
# 2021-12-29  0.005285 -0.019231  0.062766  0.009456  0.075163  0.018433
# 2021-12-30 -0.003155 -0.010893 -0.027027 -0.014052  0.024316 -0.019231
#
# Name           LG전자우        대상
# Date
# 2011-01-03  0.035360  0.010363
# 2011-01-04 -0.006605  0.012821
# 2011-01-05 -0.032155  0.001266
# 2011-01-06  0.008019 -0.006321
# 2011-01-07  0.009095  0.015267
# ...              ...       ...
# 2021-12-24 -0.001527  0.006438
# 2021-12-27  0.013761  0.004264
# 2021-12-28  0.007541  0.014862
# 2021-12-29  0.001497 -0.023013
# 2021-12-30 -0.020927 -0.002141
#
# [2711 rows x 200 columns]

# %%
correlation_matrix = df_returns.corr()
correlation_matrix
# Out:
# Name         삼성전자    SK하이닉스      LG화학     삼성SDI     삼성전자우       현대차     NAVER  \
# Name
# 삼성전자     1.000000  0.508531  0.309650  0.357653  0.804187  0.316290  0.222923
# SK하이닉스   0.508531  1.000000  0.293276  0.338306  0.434316  0.254723  0.177940
# LG화학     0.309650  0.293276  1.000000  0.493286  0.274078  0.317347  0.154619
# 삼성SDI    0.357653  0.338306  0.493286  1.000000  0.331208  0.244016  0.186306
# 삼성전자우    0.804187  0.434316  0.274078  0.331208  1.000000  0.268237  0.215835
# ...           ...       ...       ...       ...       ...       ...       ...
# 한올바이오파마  0.110811  0.165758  0.190057  0.197037  0.093879  0.109643  0.129163
# 에이프로젠    0.117905  0.129133  0.112050  0.146459  0.115472  0.104278  0.076199
# 삼천당제약    0.154998  0.200658  0.196710  0.227007  0.153971  0.157620  0.181527
# LG전자우    0.258141  0.264528  0.257214  0.255811  0.222675  0.241089  0.125330
# 대상       0.083177  0.105155  0.147994  0.131342  0.072584  0.133841  0.163478
#
# Name           기아      셀트리온       카카오  ...      태광산업     차바이오텍      삼양식품  \
# Name                                   ...
# 삼성전자     0.268189  0.106899  0.153325  ...  0.175133  0.160499  0.136869
# SK하이닉스   0.223146  0.130714  0.188175  ...  0.132089  0.180954  0.158521
# LG화학     0.282698  0.120801  0.178772  ...  0.269146  0.176953  0.167092
# 삼성SDI    0.229616  0.151861  0.229495  ...  0.188973  0.192735  0.168867
# 삼성전자우    0.221690  0.107200  0.152104  ...  0.133557  0.149471  0.126443
# ...           ...       ...       ...  ...       ...       ...       ...
# 한올바이오파마  0.107080  0.207176  0.177492  ...  0.175426  0.305929  0.183810
# 에이프로젠    0.090545  0.102681  0.138930  ...  0.122234  0.178896  0.126153
# 삼천당제약    0.147799  0.183280  0.202326  ...  0.185958  0.297213  0.160478
# LG전자우    0.254679  0.068937  0.152321  ...  0.183232  0.184521  0.157195
# 대상       0.142154  0.151638  0.169592  ...  0.218663  0.169257  0.194901
#
# Name         동원산업     바이오니아   한올바이오파마     에이프로젠     삼천당제약     LG전자우        대상
# Name
# 삼성전자     0.092058  0.070099  0.110811  0.117905  0.154998  0.258141  0.083177
# SK하이닉스   0.079391  0.099145  0.165758  0.129133  0.200658  0.264528  0.105155
# LG화학     0.095552  0.062474  0.190057  0.112050  0.196710  0.257214  0.147994
# 삼성SDI    0.083906  0.089834  0.197037  0.146459  0.227007  0.255811  0.131342
# 삼성전자우    0.095873  0.066405  0.093879  0.115472  0.153971  0.222675  0.072584
# ...           ...       ...       ...       ...       ...       ...       ...
# 한올바이오파마  0.124723  0.239195  1.000000  0.174426  0.318771  0.135183  0.206751
# 에이프로젠    0.094167  0.131480  0.174426  1.000000  0.157724  0.118202  0.114354
# 삼천당제약    0.148015  0.191233  0.318771  0.157724  1.000000  0.183048  0.180153
# LG전자우    0.100121  0.083421  0.135183  0.118202  0.183048  1.000000  0.129011
# 대상       0.178264  0.139564  0.206751  0.114354  0.180153  0.129011  1.000000
#
# [200 rows x 200 columns]

# %%
pd.options.display.float_format = '{:.5f}'.format
distance_matrix = 1-correlation_matrix
distance_matrix
# Out:
# Name       삼성전자  SK하이닉스     LG화학    삼성SDI   삼성전자우     현대차   NAVER      기아  \
# Name
# 삼성전자    0.00000 0.49147  0.69035  0.64235 0.19581 0.68371 0.77708 0.73181
# SK하이닉스  0.49147 0.00000  0.70672  0.66169 0.56568 0.74528 0.82206 0.77685
# LG화학    0.69035 0.70672 -0.00000  0.50671 0.72592 0.68265 0.84538 0.71730
# 삼성SDI   0.64235 0.66169  0.50671 -0.00000 0.66879 0.75598 0.81369 0.77038
# 삼성전자우   0.19581 0.56568  0.72592  0.66879 0.00000 0.73176 0.78416 0.77831
# ...         ...     ...      ...      ...     ...     ...     ...     ...
# 한올바이오파마 0.88919 0.83424  0.80994  0.80296 0.90612 0.89036 0.87084 0.89292
# 에이프로젠   0.88209 0.87087  0.88795  0.85354 0.88453 0.89572 0.92380 0.90945
# 삼천당제약   0.84500 0.79934  0.80329  0.77299 0.84603 0.84238 0.81847 0.85220
# LG전자우   0.74186 0.73547  0.74279  0.74419 0.77733 0.75891 0.87467 0.74532
# 대상      0.91682 0.89484  0.85201  0.86866 0.92742 0.86616 0.83652 0.85785
#
# Name       셀트리온     카카오  ...    태광산업   차바이오텍    삼양식품    동원산업   바이오니아  한올바이오파마  \
# Name                     ...
# 삼성전자    0.89310 0.84667  ... 0.82487 0.83950 0.86313 0.90794 0.92990  0.88919
# SK하이닉스  0.86929 0.81182  ... 0.86791 0.81905 0.84148 0.92061 0.90086  0.83424
# LG화학    0.87920 0.82123  ... 0.73085 0.82305 0.83291 0.90445 0.93753  0.80994
# 삼성SDI   0.84814 0.77051  ... 0.81103 0.80726 0.83113 0.91609 0.91017  0.80296
# 삼성전자우   0.89280 0.84790  ... 0.86644 0.85053 0.87356 0.90413 0.93360  0.90612
# ...         ...     ...  ...     ...     ...     ...     ...     ...      ...
# 한올바이오파마 0.79282 0.82251  ... 0.82457 0.69407 0.81619 0.87528 0.76081  0.00000
# 에이프로젠   0.89732 0.86107  ... 0.87777 0.82110 0.87385 0.90583 0.86852  0.82557
# 삼천당제약   0.81672 0.79767  ... 0.81404 0.70279 0.83952 0.85199 0.80877  0.68123
# LG전자우   0.93106 0.84768  ... 0.81677 0.81548 0.84281 0.89988 0.91658  0.86482
# 대상      0.84836 0.83041  ... 0.78134 0.83074 0.80510 0.82174 0.86044  0.79325
#
# Name       에이프로젠   삼천당제약   LG전자우      대상
# Name
# 삼성전자     0.88209 0.84500 0.74186 0.91682
# SK하이닉스   0.87087 0.79934 0.73547 0.89484
# LG화학     0.88795 0.80329 0.74279 0.85201
# 삼성SDI    0.85354 0.77299 0.74419 0.86866
# 삼성전자우    0.88453 0.84603 0.77733 0.92742
# ...          ...     ...     ...     ...
# 한올바이오파마  0.82557 0.68123 0.86482 0.79325
# 에이프로젠   -0.00000 0.84228 0.88180 0.88565
# 삼천당제약    0.84228 0.00000 0.81695 0.81985
# LG전자우    0.88180 0.81695 0.00000 0.87099
# 대상       0.88565 0.81985 0.87099 0.00000
#
# [200 rows x 200 columns]

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Installing collected packages: sklearn
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# Successfully installed sklearn-0.0.post1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(distance_matrix, 'ward')
linked
labelList = range(len(distance_matrix))

plt.figure(figsize=(20, 10))
dendrogram(
    linked,
    orientation='top',
    labels=labelList,
    distance_sort='descending',
    show_leaf_counts=True
)

plt.xticks(rotation=-90)
plt.tick_params(axis='x', labelcolor='white', bottom=True)
plt.tick_params(axis='y', labelcolor='white', top=True)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# TODO: how to choose num_clusters
num_clusters = 20

model = AgglomerativeClustering(n_clusters=num_clusters , affinity='euclidean', linkage='ward')
clst_labels = model.fit_predict(distance_matrix)
clst_labels
# Out:
# array([10, 10, 11, 10, 10,  8, 12,  8,  9, 12,  2,  8, 13, 13,  0, 11, 15,
#        10, 15, 11, 19, 16, 13, 19, 19, 10, 16, 12,  4, 11, 16, 11, 18, 19,
#        14,  0, 13, 10, 18,  6,  5, 11,  2, 10, 16, 19,  5,  2,  2,  1,  6,
#        11, 11,  3,  2, 16, 19, 17,  9, 14, 14,  2, 15, 15,  5,  0, 15,  3,
#        17, 17, 17,  8,  4,  7, 16, 16, 15,  5,  9, 14, 11,  7,  4, 11, 19,
#         0, 16, 18,  3,  0,  5, 16,  4,  1,  2,  2,  7,  5,  2,  2,  0,  0,
#         5, 12,  2,  8,  5, 12,  5, 15,  1,  4,  3,  5,  5,  0,  9,  9,  1,
#         2,  0, 16,  2, 12,  4, 16, 16,  0,  3,  6,  7,  4, 16,  0,  4,  0,
#         4,  7, 15,  5,  2, 16,  9,  4,  0,  0,  4,  3,  0,  6,  9,  2,  9,
#         4,  4, 12,  0,  0,  1, 12, 16,  7,  9,  0,  0,  9, 12, 16,  4,  5,
#        11,  1,  4,  5,  0,  0, 12, 15,  0,  0,  7, 16,  4,  4,  5,  2,  1,
#         3,  1,  9, 15,  3, 12,  4,  9,  3,  9,  3, 10,  5], dtype=int64)

# %%
df_clst_num = pd.DataFrame(clst_labels)
df_clst_num.columns = ["cluster_number"]
df_clst_num
# Out:
#      cluster_number
# 0                10
# 1                10
# 2                11
# 3                10
# 4                10
# ..              ...
# 195               3
# 196               9
# 197               3
# 198              10
# 199               5
#
# [200 rows x 1 columns]

# %%
df_clst_num["cluster_number"].value_counts()
# Out:
# 0     23
# 4     18
# 16    17
# 2     16
# 5     16
# 9     13
# 11    11
# 12    11
# 3     10
# 15    10
# 10     9
# 1      8
# 19     7
# 7      7
# 8      5
# 14     4
# 6      4
# 13     4
# 17     4
# 18     3
# Name: cluster_number, dtype: int64

# %% [markdown]
# # Clustering Evaluation

# %% [markdown]
# ## silhoutte coefficient

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
silhouette = silhouette_samples(distance_matrix, clst_labels)

silhouette
# Out:
# array([ 2.84700613e-01,  1.88356180e-01,  2.66901135e-01,  9.96427767e-02,
#         2.10857669e-01,  6.05664958e-01,  1.22959048e-01,  5.07932763e-01,
#         9.56534057e-02,  1.56988513e-01,  4.14593346e-02,  4.62553471e-01,
#         6.51365630e-01,  6.54095441e-01,  1.57695993e-01,  1.85694090e-01,
#         5.01906086e-02,  2.20479328e-01, -1.09459541e-01,  4.99690856e-02,
#         1.08752478e-01, -2.55890854e-03,  6.31745033e-01,  7.11563255e-02,
#         2.15841972e-01,  2.25383806e-01,  7.63134211e-02,  1.06788540e-01,
#         8.30310808e-02,  1.43460506e-01,  4.85757610e-02,  1.23237840e-01,
#         3.75317054e-01,  4.05295793e-02,  3.28583602e-01,  1.85465087e-01,
#         5.87614397e-01,  1.61707830e-01,  5.15851082e-01,  1.56771979e-02,
#         8.70534688e-02,  1.93051440e-01,  2.21616838e-01,  1.57192360e-01,
#        -2.19632577e-02,  1.94565019e-01, -2.83507395e-02,  2.17553383e-01,
#         2.00235565e-01, -3.71036337e-02,  2.03208570e-01,  5.30502906e-02,
#         1.23261099e-01,  1.83294545e-01,  1.14687481e-01, -7.84417588e-02,
#        -6.13513893e-03,  6.37235103e-01,  7.82660601e-02,  3.95770866e-01,
#         2.87106757e-01,  2.30008724e-01, -1.65773790e-02,  1.26447190e-02,
#        -2.97282540e-02,  2.10116847e-01,  6.71042025e-02,  2.27152222e-01,
#         4.31159865e-01,  6.49843938e-01,  6.31130248e-01,  5.08454076e-01,
#         7.09876953e-02,  9.57404074e-02,  3.19549943e-02, -2.73147111e-02,
#         2.31646549e-02,  5.72021033e-02, -3.58853189e-02,  4.40817009e-01,
#         2.24714589e-01,  7.05218637e-02,  5.44656108e-02,  6.83200790e-02,
#         5.20353273e-02,  1.29917819e-01, -1.66832175e-01,  4.54034787e-01,
#         2.60178953e-01, -2.93599066e-03, -3.41094303e-02,  2.12461048e-02,
#         7.57784801e-02, -1.11978047e-02,  1.65843366e-01,  7.27252495e-02,
#         1.95767220e-01,  5.74504549e-02,  1.49621279e-01,  2.17833020e-01,
#         7.30509806e-02,  2.11067779e-01,  5.05557878e-04,  9.83830378e-02,
#         2.18145214e-01,  5.76898135e-01,  1.92518062e-02,  1.54760913e-01,
#         6.40582022e-02, -8.60527471e-02,  3.57211499e-02,  4.79495489e-03,
#         2.47704642e-01, -3.68277847e-02, -6.59005641e-02,  1.46883209e-01,
#         1.58612063e-02,  1.07461113e-01,  2.81353698e-02,  1.05198216e-01,
#         2.25547545e-03,  2.29150779e-02,  1.15554837e-01,  9.47643959e-02,
#         5.83195848e-03,  8.33664367e-02,  3.17230035e-02,  2.03548913e-02,
#         2.26665523e-01,  8.46691609e-02,  1.90154712e-01,  2.45710746e-02,
#        -6.40727192e-02,  1.48780010e-01, -5.53253542e-02,  9.26041060e-02,
#         4.44464117e-02,  1.73579037e-01,  9.22403935e-02,  6.30858197e-02,
#         1.78487484e-01,  7.17559927e-02,  6.65656452e-02,  4.21311878e-02,
#         1.39226604e-01,  1.66858550e-01,  5.31419931e-02,  1.95709308e-01,
#         8.71490136e-02,  1.35052623e-01,  4.70537623e-02,  1.85526785e-01,
#         8.74222832e-02,  2.90278171e-02,  2.97520657e-02,  1.14374264e-01,
#         1.68568260e-03,  1.36418797e-02, -1.32342391e-02,  6.98064883e-02,
#         8.70332352e-02,  1.58973353e-01,  6.47744775e-02,  2.03391648e-02,
#         1.15991735e-01,  1.70903408e-02,  1.72291790e-01,  3.83550868e-02,
#        -8.10324486e-02, -3.60264868e-02,  1.16778982e-01, -3.08113629e-03,
#         5.90108854e-02, -8.68431365e-02,  1.57114263e-01,  1.47966397e-01,
#         1.64783623e-01, -5.58153277e-03,  8.83716314e-02,  1.11872010e-01,
#         1.85534451e-01,  7.07278967e-02,  1.85300116e-02,  3.02695293e-02,
#        -9.12664547e-02,  1.08567594e-01,  2.19795188e-02,  2.64739853e-01,
#        -7.21523548e-02, -1.76477557e-02,  3.62553968e-02,  2.74418812e-02,
#         4.99314778e-02,  1.09642485e-02,  1.39901991e-01,  2.04025243e-01,
#         2.57428774e-02,  9.82835589e-03,  1.92467543e-01,  8.14914250e-02])

# %%
df_for_silhouette = pd.DataFrame(data = {'cluster_number': clst_labels, 'silhouette_coefficient': silhouette})
df_for_silhouette.groupby('cluster_number').mean()
# Out:
#                 silhouette_coefficient
# cluster_number
# 0                              0.10546
# 1                             -0.00637
# 2                              0.15894
# 3                              0.18467
# 4                              0.02780
# 5                              0.00132
# 6                              0.10965
# 7                              0.15290
# 8                              0.53230
# 9                              0.05325
# 10                             0.19342
# 11                             0.14077
# 12                             0.11871
# 13                             0.63121
# 14                             0.36307
# 15                             0.00639
# 16                             0.01310
# 17                             0.58734
# 18                             0.44840
# 19                             0.09668

# %%
silhouette_score = silhouette_score(distance_matrix, clst_labels)
silhouette_score
# Out:
# 0.1268929907206248

# %% [markdown]
# # K-means clustering
