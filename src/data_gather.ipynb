# %%
pip install finance-datareader
# Out:
# Requirement already satisfied: finance-datareader in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.9.50)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (1.4.0)
# Requirement already satisfied: requests-file in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (1.5.1)
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (4.64.0)
# Requirement already satisfied: requests>=2.3.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (2.27.1)
# Requirement already satisfied: lxml in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from finance-datareader) (4.9.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=0.19.2->finance-datareader) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.3.0->finance-datareader) (3.3)
# Requirement already satisfied: six in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-file->finance-datareader) (1.16.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->finance-datareader) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.6.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install bs4
# Out:
# Requirement already satisfied: bs4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX-MARCAP')
df_krx
# Out:
#         Code        ISU_CD      Name Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자  KOSPI          60200          1
# 1     373220  KR7373220003  LG에너지솔루션  KOSPI         587000          2
# 2     000660  KR7000660001    SK하이닉스  KOSPI          86500          1
# 3     207940  KR7207940008  삼성바이오로직스  KOSPI         883000          1
# 4     006400  KR7006400006     삼성SDI  KOSPI         740000          1
# ...      ...           ...       ...    ...    ...     ...        ...
# 2665  308700  KR7308700004       테크엔  KONEX  일반기업부     647          1
# 2666  267810  KR7267810000        앙츠  KONEX  일반기업부    1170          1
# 2667  215050  KR7215050006   비엔디생활건강  KONEX  일반기업부     912          0
# 2668  267060  KR7267060002     명진홀딩스  KONEX  일반기업부     181          0
# 2669  329020  KR7329020002      오션스톤  KONEX  일반기업부    1800          0
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# 0         800         1.35   59700   60300   59400  12437246  747350127100
# 1       -5000        -0.84  591000  596000  581000    260646  152981620000
# 2        2000         2.37   85400   86800   85000   2765284  238246097100
# 3       12000         1.38  879000  886000  870000     45877   40334179000
# 4        7000         0.95  742000  749000  733000    235945  174640374000
# ...       ...          ...     ...     ...     ...       ...           ...
# 2665       33         5.37     647     647     647         1           647
# 2666       20         1.74    1250    1250    1170        35         43670
# 2667        0         0.00       0       0       0         0             0
# 2668        0         0.00       0       0       0         0             0
# 2669        0         0.00       0       0       0         0             0
#
#                Marcap      Stocks MarketId
# 0     359380909510000  5969782550      STK
# 1     137358000000000   234000000      STK
# 2      62972204572500   728002365      STK
# 3      62846642000000    71174000      STK
# 4      50885752200000    68764530      STK
# ...               ...         ...      ...
# 2665       2588000000     4000000      KNX
# 2666       2090790000     1787000      KNX
# 2667       1934959392     2121666      KNX
# 2668       1654666524     9141804      KNX
# 2669       1503273600      835152      KNX
#
# [2670 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df_krx["Marcap"])
plt.show()

# %%
num_stocks = 300

plt.plot(df_krx["Marcap"][:num_stocks])
plt.show()

# %%
start_date = '2010-12-30'
end_date = '2021-12-30'
df_list = []

for code in df_krx["Code"][:num_stocks]:
    series_close = fdr.DataReader(code, start_date, end_date)["Close"]
    df_list.append(series_close)

df_close = pd.concat(df_list, axis=1)
df_close.columns = df_krx["Name"][:num_stocks]
df_close
# Out:
# Name         삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스   삼성SDI    LG화학  삼성전자우     현대차  \
# Date
# 2010-12-30  18980       NaN   24000       NaN  168000  391000  12980  173500
# 2011-01-03  19160       NaN   25300       NaN  178000  390500  13740  177000
# 2011-01-04  19160       NaN   25600       NaN  179000  395000  13820  178000
# 2011-01-05  18840       NaN   25900       NaN  178000  418000  13580  189000
# 2011-01-06  18600       NaN   26100       NaN  180500  418000  13420  194000
# ...           ...       ...     ...       ...     ...     ...    ...     ...
# 2021-12-24  80500       NaN  128000  874642.0  651000  621000  72800  215500
# 2021-12-27  80200       NaN  126000  875631.0  644000  627000  72400  213500
# 2021-12-28  80300       NaN  127500  880572.0  651000  632000  72400  214000
# 2021-12-29  78800       NaN  127000  879584.0  663000  628000  71700  212000
# 2021-12-30  78300       NaN  131000  892432.0  655000  615000  71200  209000
#
# Name         NAVER     기아  ...     풍산     대상     선광  롯데관광개발  LG전자우  한올바이오파마  \
# Date                       ...
# 2010-12-30   71256  50600  ...  48000   7720  16950   16132  41092     7360
# 2011-01-03   69529  52500  ...  48200   7800  17000   16450  42545     6990
# 2011-01-04   69529  55100  ...  48200   7900  16900   16698  42264     7030
# 2011-01-05   69843  56900  ...  48750   7910  16550   17051  40905     7050
# 2011-01-06   69529  57100  ...  48550   7860  16550   16556  41233     6970
# ...            ...    ...  ...    ...    ...    ...     ...    ...      ...
# 2021-12-24  384000  85100  ...  31450  23450  56600   17600  65400    20700
# 2021-12-27  380500  84800  ...  31450  23550  56300   17350  66300    21500
# 2021-12-28  384500  84500  ...  31600  23900  57000   17150  66800    21150
# 2021-12-29  382000  83400  ...  31400  23350  58300   17700  66900    21350
# 2021-12-30  378500  82200  ...  31150  23300  58100   17550  65500    21050
#
# Name         이수화학  영원무역홀딩스  넥센타이어   동국제약
# Date
# 2010-12-30  17487    36650   8400   2893
# 2011-01-03  17623    34650   8490   2943
# 2011-01-04  17532    35350   8640   2983
# 2011-01-05  17306    34950   8820   2943
# 2011-01-06  18076    35700   8750   2903
# ...           ...      ...    ...    ...
# 2021-12-24  14550    47450   6710  21700
# 2021-12-27  14450    47600   6860  22400
# 2021-12-28  14500    48400   6910  22550
# 2021-12-29  14900    47150   6890  21950
# 2021-12-30  14550    46750   6820  21800
#
# [2712 rows x 300 columns]

# %%
df_close = df_close.dropna(axis=1)
df_close
# Out:
# Name         삼성전자  SK하이닉스   삼성SDI    LG화학  삼성전자우     현대차   NAVER     기아  \
# Date
# 2010-12-30  18980   24000  168000  391000  12980  173500   71256  50600
# 2011-01-03  19160   25300  178000  390500  13740  177000   69529  52500
# 2011-01-04  19160   25600  179000  395000  13820  178000   69529  55100
# 2011-01-05  18840   25900  178000  418000  13580  189000   69843  56900
# 2011-01-06  18600   26100  180500  418000  13420  194000   69529  57100
# ...           ...     ...     ...     ...    ...     ...     ...    ...
# 2021-12-24  80500  128000  651000  621000  72800  215500  384000  85100
# 2021-12-27  80200  126000  644000  627000  72400  213500  380500  84800
# 2021-12-28  80300  127500  651000  632000  72400  214000  384500  84500
# 2021-12-29  78800  127000  663000  628000  71700  212000  382000  83400
# 2021-12-30  78300  131000  655000  615000  71200  209000  378500  82200
#
# Name          셀트리온  POSCO홀딩스  ...     풍산     대상     선광  롯데관광개발  LG전자우  \
# Date                          ...
# 2010-12-30   28015    487000  ...  48000   7720  16950   16132  41092
# 2011-01-03   28056    486000  ...  48200   7800  17000   16450  42545
# 2011-01-04   27597    499500  ...  48200   7900  16900   16698  42264
# 2011-01-05   27847    507000  ...  48750   7910  16550   17051  40905
# 2011-01-06   28517    507000  ...  48550   7860  16550   16556  41233
# ...            ...       ...  ...    ...    ...    ...     ...    ...
# 2021-12-24  197278    284000  ...  31450  23450  56600   17600  65400
# 2021-12-27  200222    281500  ...  31450  23550  56300   17350  66300
# 2021-12-28  212000    283500  ...  31600  23900  57000   17150  66800
# 2021-12-29  201000    279000  ...  31400  23350  58300   17700  66900
# 2021-12-30  198000    274500  ...  31150  23300  58100   17550  65500
#
# Name        한올바이오파마   이수화학  영원무역홀딩스  넥센타이어   동국제약
# Date
# 2010-12-30     7360  17487    36650   8400   2893
# 2011-01-03     6990  17623    34650   8490   2943
# 2011-01-04     7030  17532    35350   8640   2983
# 2011-01-05     7050  17306    34950   8820   2943
# 2011-01-06     6970  18076    35700   8750   2903
# ...             ...    ...      ...    ...    ...
# 2021-12-24    20700  14550    47450   6710  21700
# 2021-12-27    21500  14450    47600   6860  22400
# 2021-12-28    21150  14500    48400   6910  22550
# 2021-12-29    21350  14900    47150   6890  21950
# 2021-12-30    21050  14550    46750   6820  21800
#
# [2712 rows x 200 columns]

# %%
df_returns = df_close.pct_change()
df_returns = df_returns.iloc[1:, :]
df_returns
# Out:
# Name            삼성전자    SK하이닉스     삼성SDI      LG화학     삼성전자우       현대차  \
# Date
# 2011-01-03  0.009484  0.054167  0.059524 -0.001279  0.058552  0.020173
# 2011-01-04  0.000000  0.011858  0.005618  0.011524  0.005822  0.005650
# 2011-01-05 -0.016701  0.011719 -0.005587  0.058228 -0.017366  0.061798
# 2011-01-06 -0.012739  0.007722  0.014045  0.000000 -0.011782  0.026455
# 2011-01-07 -0.009677  0.000000 -0.013850 -0.005981 -0.011923  0.020619
# ...              ...       ...       ...       ...       ...       ...
# 2021-12
# 넥센타이어    0.129236  0.192444  0.143872  0.234738  0.175475  1.000000  0.141223
# 동국제약     0.086711  0.144240  0.277371  0.157128  0.150563  0.141223  1.000000
#
# [200 rows x 200 columns]

# %%
pd.options.display.float_format = '{:.5f}'.format
distance_matrix = 1-correlation_matrix
distance_matrix
# Out:
# Name       삼성전자  SK하이닉스    삼성SDI     LG화학   삼성전자우     현대차   NAVER      기아  \
# Name
# 삼성전자    0.00000 0.49147  0.64235  0.69035 0.19581 0.68371 0.77708 0.73181
# SK하이닉스  0.49147 0.00000  0.66169  0.70672 0.56568 0.74528 0.82206 0.77685
# 삼성SDI   0.64235 0.66169 -0.00000  0.50671 0.66879 0.75598 0.81369 0.77038
# LG화학    0.69035 0.70672  0.50671 -0.00000 0.72592 0.68265 0.84538 0.71730
# 삼성전자우   0.19581 0.56568  0.66879  0.72592 0.00000 0.73176 0.78416 0.77831
# ...         ...     ...      ...      ...     ...     ...     ...     ...
# 한올바이오파마 0.88919 0.83424  0.80296  0.80994 0.90612 0.89036 0.87084 0.89292
# 이수화학    0.80212 0.77789  0.77116  0.71172 0.82046 0.78351 0.88082 0.78181
# 영원무역홀딩스 0.86611 0.86643  0.86065  0.89463 0.88957 0.85442 0.90535 0.83545
# 넥센타이어   0.81745 0.82510  0.79564  0.75758 0.87521 0.66751 0.88159 0.64115
# 동국제약    0.87672 0.84603  0.86809  0.85845 0.90132 0.90419 0.84410 0.91317
#
# Name       셀트리온  POSCO홀딩스  ...      풍산      대상      선광  롯데관광개발   LG전자우  \
# Name                       ...
# 삼성전자    0.89310   0.68569  ... 0.69302 0.91682 0.79878 0.88705 0.74186
# SK하이닉스  0.86929   0.73737  ... 0.71828 0.89484 0.79581 0.89070 0.73547
# 삼성SDI   0.84814   0.79781  ... 0.71144 0.86866 0.78898 0.87566 0.74419
# LG화학    0.87920   0.65989  ... 0.62190 0.85201 0.75970 0.85022 0.74279
# 삼성전자우   0.89280   0.72648  ... 0.73832 0.92742 0.82364 0.89559 0.77733
# ...         ...       ...  ...     ...     ...     ...     ...     ...
# 한올바이오파마 0.79282   0.85657  ... 0.79041 0.79325 0.81414 0.91028 0.86482
# 이수화학    0.86625   0.74134  ... 0.66247 0.80311 0.73973 0.87827 0.81190
# 영원무역홀딩스 0.91265   0.84931  ... 0.80543 0.85745 0.85983 0.88118 0.87456
# 넥센타이어   0.94328   0.75303  ... 0.70866 0.82930 0.86376 0.87076 0.80756
# 동국제약    0.83387   0.92274  ... 0.84192 0.79798 0.86892 0.91329 0.85576
#
# Name     한올바이오파마     이수화학  영원무역홀딩스    넥센타이어     동국제약
# Name
# 삼성전자     0.88919  0.80212  0.86611  0.81745  0.87672
# SK하이닉스   0.83424  0.77789  0.86643  0.82510  0.84603
# 삼성SDI    0.80296  0.77116  0.86065  0.79564  0.86809
# LG화학     0.80994  0.71172  0.89463  0.75758  0.85845
# 삼성전자우    0.90612  0.82046  0.88957  0.87521  0.90132
# ...          ...      ...      ...      ...      ...
# 한올바이오파마  0.00000  0.80108  0.87601  0.85613  0.72263
# 이수화학     0.80108 -0.00000  0.83880  0.76526  0.84287
# 영원무역홀딩스  0.87601  0.83880 -0.00000  0.82453  0.84944
# 넥센타이어    0.85613  0.76526  0.82453 -0.00000  0.85878
# 동국제약     0.72263  0.84287  0.84944  0.85878 -0.00000
#
# [200 rows x 200 columns]

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.3-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 7.5/7.5 MB 13.4 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 6.1 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
#      --------------------------------------- 40.1/40.1 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->sklearn) (1.22.2)
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 28] No space left on device
#
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: C:\Users\user\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.cluster import AgglomerativeClustering

num_clusters = 50

model = AgglomerativeClustering(n_clusters=num_clusters , affinity='euclidean', linkage='ward')
model.fit_predict(distance_matrix)
# Out:
# array([38, 26, 26, 19, 38, 39, 21, 39, 27,  1, 21, 39, 31, 31, 48, 18, 10,
#        24, 14, 15, 19, 31, 11, 42, 15, 48, 28, 29, 22, 42, 26, 12, 44, 43,
#        21, 31, 18, 26,  3,  2, 44, 12, 47, 11, 42,  7, 26, 47, 48,  6, 33,
#         3, 12, 17,  1, 29, 15, 45, 40, 16, 47,  7, 29, 10, 14, 18, 14, 17,
#        29, 16, 39, 16, 16, 22, 11,  7, 13, 10, 25, 37, 19, 27, 34, 15, 12,
#        17,  1,  8, 44,  6, 11, 13, 41,  2, 35, 37,  1,  7, 35, 18, 47,  2,
#        33, 33, 39, 23,  2,  8, 36,  4, 49, 46, 14,  2,  7,  1,  9,  8,  0,
#         1, 35, 45, 36, 34,  3, 17, 45, 30, 28, 18, 20, 20, 25, 23, 23, 37,
#        33, 28,  2, 45, 18, 46,  3,  5,  1, 23, 35, 40,  0, 10,  0,  5,  8,
#        22, 20, 11, 30, 25,  6,  4,  4, 23, 30,  0, 18,  0,  3,  2,  5, 12,
#        43, 10,  8,  4,  4,  5,  9, 23, 30,  4, 20,  5, 35, 23, 10, 25,  6,
#        17,  0, 32,  1,  2, 30,  8, 24, 32, 45, 41,  3, 32], dtype=int64)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(distance_matrix, 'ward')
linked
labelList = range(len(distance_matrix))

plt.figure(figsize=(20, 10))
dendrogram(
    linked,
    orientation='top',
    labels=labelList,
    distance_sort='descending',
    show_leaf_counts=True
)

plt.xticks(rotation=-90)
plt.tick_params(axis='x', labelcolor='white', bottom=True)
plt.tick_params(axis='y', labelcolor='white', top=True)
plt.show()
